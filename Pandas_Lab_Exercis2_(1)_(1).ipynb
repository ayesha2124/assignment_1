# %% [markdown]
# ## Pandas Lab Exercise (Kaggle Automobile Dataset)
#
# We shall now test your skills in using Pandas package. We will be using the [automobiles Dataset](https://www.kaggle.com/nisargpatel/automobiles/data) from Kaggle.
#
# Answer each question asked below wrt the automobiles dataset. Load pandas as pd and upload the Automobile.csv file as auto

# %%
import pandas as pd

# %% [markdown]
# **Load the Automobile dataset into variable "auto"**

# %%
import pandas as pd
df=pd.read_csv('/content/Automobile.csv');
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# ..              ...          ...          ...             ...         ...
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0    ...          130         mpfi  3.47    2.68               9.0        111
# 1    ...          130         mpfi  3.47    2.68               9.0        111
# 2    ...          152         mpfi  2.68    3.47               9.0        154
# 3    ...          109         mpfi  3.19    3.40              10.0        102
# 4    ...          136         mpfi  3.19    3.40               8.0        115
# ..   ...          ...          ...   ...     ...               ...        ...
# 196  ...          141         mpfi  3.78    3.15               9.5        114
# 197  ...          141         mpfi  3.78    3.15               8.7        160
# 198  ...          173         mpfi  3.58    2.87               8.8        134
# 199  ...          145          idi  3.01    3.40              23.0        106
# 200  ...          141         mpfi  3.78    3.15               9.5        114
#
#      peak_rpm city_mpg  highway_mpg  price
# 0        5000       21           27  13495
# 1        5000       21           27  16500
# 2        5000       19           26  16500
# 3        5500       24           30  13950
# 4        5500       18           22  17450
# ..        ...      ...          ...    ...
# 196      5400       23           28  16845
# 197      5300       19           25  19045
# 198      5500       18           23  21485
# 199      4800       26           27  22470
# 200      5400       19           25  22625
#
# [201 rows x 26 columns]

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# **How many rows and columns are there?**

# %%
df.shape[0]#for rows it should be 0 becoz first element is 0 it is row
# Out:
# 201

# %%
df.shape[1]#for col it should be 1 becoz second element is 1 it is
# Out:
# 26

# %% [markdown]
# **What is the average Price of all cars in the dataset?**

# %%
avg=df['price'].mean()
avg
# Out:
# 13207.129353233831

# %% [markdown]
# **Which is the cheapest make and costliest make of car in the lot?**

# %%
#cheapset
a=df.sort_values(by=['price'], ascending=True).head(1)
a[['make','price']]
# Out:
#        make  price
# 134  subaru   5118

# %%
#costilest

a=df.sort_values(by=['price'], ascending=False).head(1)
a[['make','price']]
# Out:
#              make  price
# 71  mercedes-benz  45400

# %% [markdown]
# **How many cars have horsepower greater than 100?**

# %%
#by using count
a=df[df['horsepower']>100]
a['horsepower'].count()

#by using shape function
a=df[df['horsepower']>100].shape[0]
a
# Out:
# 90

# %% [markdown]
# **How many hatchback cars are in the dataset ?**

# %%
a=df['body_style']=='hatchback'

# %%
b=a.sum()
b
# Out:
# 68

# %% [markdown]
# **What are the 3 most commonly found cars in the dataset?**

# %%
commonly_used_cars = df['make']

# %%
commonly_used_cars.value_counts().head(3)
# Out:
# make
# toyota    32
# nissan    18
# mazda     17
# Name: count, dtype: int64

# %% [markdown]
# **Someone purchased a car for 7099, what is the make of the car?**

# %%
a=df[df['price']==7099];
a['make']
# Out:
# 87    nissan
# Name: make, dtype: object

# %% [markdown]
# **Which cars are priced greater than 40000?**

# %%
priced=df[df['price']>40000];
priced['make']
# Out:
# 15              bmw
# 70    mercedes-benz
# 71    mercedes-benz
# Name: make, dtype: object

# %% [markdown]
# **Which are the cars that are both a sedan and priced less than 7000?**

# %%
cars=df[(df['body_style']=='sedan') & df['price']<7000]
cars['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 196          volvo
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# Name: make, Length: 201, dtype: object

# %% [markdown]
#  **Count the number of unique values in the `fuel_type` column.**

# %%
df['fuel_type'].nunique()
# Out:
# 2

# %% [markdown]
# **List all the cars that have a horsepower between 100 and 200, and display their `make`, `horsepower`, and `price`.**

# %%
valuescars = df[(df['horsepower'] >= 100) & (df['horsepower'] <= 200)]
df[['make', 'horsepower', 'price']]
# Out:
#             make  horsepower  price
# 0    alfa-romero         111  13495
# 1    alfa-romero         111  16500
# 2    alfa-romero         154  16500
# 3           audi         102  13950
# 4           audi         115  17450
# ..           ...         ...    ...
# 196        volvo         114  16845
# 197        volvo         160  19045
# 198        volvo         134  21485
# 199        volvo         106  22470
# 200        volvo         114  22625
#
# [201 rows x 3 columns]

# %% [markdown]
# **Find the average `city_mpg` and `highway_mpg` for each `body_style`.**

# %%
avg=df.groupby('body_style')[['city_mpg', 'highway_mpg']].mean()
avg
# Out:
#               city_mpg  highway_mpg
# body_style
# convertible  20.500000    26.000000
# hardtop      21.625000    27.250000
# hatchback    26.602941    32.382353
# sedan        25.053191    30.574468
# wagon        24.040000    28.720000

# %% [markdown]
# **What is the median `price` for each `make`?**

# %%
df.groupby('make')['price'].median()
# Out:
# make
# alfa-romero      16500.0
# audi             17580.0
# bmw              22835.0
# chevrolet         6295.0
# dodge             7609.0
# honda             7295.0
# isuzu             8916.5
# jaguar           35550.0
# mazda            10595.0
# mercedes-benz    32892.0
# mercury          16503.0
# mitsubishi        8499.0
# nissan            8124.0
# peugot           16630.0
# plymouth          7609.0
# porsche          33278.0
# renault           9595.0
# saab             15275.0
# subaru            7894.0
# toyota            9103.0
# volkswagen        9737.5
# volvo            18420.0
# Name: price, dtype: float64

# %% [markdown]
# **List all cars that have a `wheel_base` greater than 100 and a `curb_weight` less than 2500.**

# %%
cars=df[(df['wheel_base']>100) & (df['curb_weight']<2500)]
cars['make']
# Out:
# 9         bmw
# 10        bmw
# 169    toyota
# 170    toyota
# 171    toyota
# 172    toyota
# 173    toyota
# Name: make, dtype: object

# %% [markdown]
# **Create a new column `price_per_hp` that calculates the price of the car per horsepower.**

# %%
df['price_per_hp']=df['price']/df['horsepower']
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# ..              ...          ...          ...             ...         ...
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  \
# 0    ...         mpfi  3.47    2.68                9.0        111     5000
# 1    ...         mpfi  3.47    2.68                9.0        111     5000
# 2    ...         mpfi  2.68    3.47                9.0        154     5000
# 3    ...         mpfi  3.19    3.40               10.0        102     5500
# 4    ...         mpfi  3.19    3.40                8.0        115     5500
# ..   ...          ...   ...     ...                ...        ...      ...
# 196  ...         mpfi  3.78    3.15                9.5        114     5400
# 197  ...         mpfi  3.78    3.15                8.7        160     5300
# 198  ...         mpfi  3.58    2.87                8.8        134     5500
# 199  ...          idi  3.01    3.40               23.0        106     4800
# 200  ...         mpfi  3.78    3.15                9.5        114     5400
#
#      city_mpg highway_mpg  price  price_per_hp
# 0          21          27  13495    121.576577
# 1          21          27  16500    148.648649
# 2          19          26  16500    107.142857
# 3          24          30  13950    136.764706
# 4          18          22  17450    151.739130
# ..        ...         ...    ...           ...
# 196        23          28  16845    147.763158
# 197        19          25  19045    119.031250
# 198        18          23  21485    160.335821
# 199        26          27  22470    211.981132
# 200        19          25  22625    198.464912
#
# [201 rows x 27 columns]

# %% [markdown]
# **Count how many cars have a `number_of_doors` as `four`.**

# %%
cars=(df['number_of_doors']=='four').sum()
cars
# Out:
# 114

# %% [markdown]
# **Find the top 5 cars based on their `highway_mpg` and `price`.**

# %%
top_cars = df.groupby(['make']).agg({'highway_mpg': 'max', 'price': 'max'})
top_cars.sort_values(by=['highway_mpg', 'price'], ascending=[False, False]).head(5)
# by dropping the duplicates
#top_cars = df.sort_values(by=['highway_mpg', 'price'], ascending=[False, False]).drop_duplicates(subset=['make'])
#top_cars.head(5)
# Out:
#             highway_mpg  price
# make
# honda                54  12945
# chevrolet            53   6575
# nissan               50  19699
# toyota               47  17669
# volkswagen           46  13845

# %% [markdown]
# **How many cars have missing values in the `normalized_losses` column?**

# %%
df['normalized_losses'].isnull().sum()
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price', 'price_per_hp'],
#       dtype='object')

# %% [markdown]
# **Create a new column `car_age` that calculates the age of the car based on the `year_of_manufacture` (assume the current year is 2025).**

# %% [markdown]
# ### The END
